# %% [markdown]
# #Excel basics Assignment
# 1. Expain the difference between Relative, Absolutes and Mixed Cell Referencing.
#
#   **Ans->** **Reletive** **Referance**- this is the differance when I put the formula cell referance change autometically.
#
#
# Absolute Referance- The cell referance never changes because column and row are locked by the using "$".
#
# Mix Referance- 1 column is fixed and row are changing.

# %% [markdown]
# 2. Write a formula to colculates the total sales of Car and Bicyle only.
#
#   Ans-> Let A and B column for Car and Bicycle Respectively then,
#    =SUMPRODUCT(A2:A3,B2:B3)

# %% [markdown]
# 3. Using the data below, write a formula to calculate the average of items priced above 100 but less than 300:
#
# Ans-> Because the price of rows B3 and B4 is more than 100 and less than 300 then,
#
# Formula-> =Average(B3:B4)

# %% [markdown]
# **Note: Use the following Datasats and solve the following quations.**
#
# 4. Count how many customer names are recorded.
#
# Ans-> 50, Formula-> =COUNTA(B2:B51)
#
# 5. Calculate the Total Sales for each row using a formula.
#
# Ans-> 1003, Formula-> =SUM(B2:B51)
#
# 6. Calculate the total sales of Notebooks in the North region only.
#
# Ans-> sorry Sir I don't understand this question. But I'm still learning thank you.
# 7.
